# %% [markdown]
# ## Introduction
#
# - gwps per year
# - theme of gwp
# - number of parts
# - number of minifigures
# - exclusive minifigures
# - minimum price
# - exclusive for theme or set
# - runtime
