# %% [markdown]
# ## Introduction
#
# Here, we clarify questions like:
# - What is the most colorful set? --> Hook: New aquarium where designer wanted to "use all colors"
# - What brick comes in most colors?
# - Which color provides the most bricks?
# - How did colorfulness change over the years?
# - What is the most colorful theme?
# - Does number of color relate to price? --> basic, hint to dedicated article on lego price
# - How large is color variance depending on theme / number of bricks / etc.? --> make this more basic and then hint to a more detailed article on color variance.
