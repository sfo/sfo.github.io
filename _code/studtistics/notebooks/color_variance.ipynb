# %% [markdown]
# ## Introduction
#
# - How did color variance in sets change over the years? --> this might be worth a different article to clarify more questions like:
#   - Did color variety change (increase) over the years?
#   - How does color variety relate to brick variety?
#   - Does color variance relate to number of alternate builds? --> check argument for "Farbseuche verhindert das Umbauen von Sets."
