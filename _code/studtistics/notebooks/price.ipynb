# %% [markdown]
# ## Introduction
#
# This will try to sched some light on the most emotional debate in LEGO cosmos: Does Lego become increasingly more expensive over the last couple of years?
# Additionally, we investigate questions like:
# - How did LEGO set price develop over the years? (include inflation)
# - How did set size develop over the years?
# - How did set weight develop over the years?
# - How did price develop over the years in relation to piece count / weight?
#
# Maybe this would be worth another article: Reverse engineer lego prices
# - Is price related to the number of pieces?
# - Is price related to a set's weight?
# - Is price related to the number of different moulds or bricks?
# - Is price related to some combination of those?
