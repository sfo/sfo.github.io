# %% [markdown]
# ## Introduction
#
# - which franchise is the largest (cf. Quatschen und Bauen #150 where they discuss, whether Star Trek or Lord of the Rings is the bigger franchies)
# - also there is a comment on "probably over 1,000" set for the Star Wars theme --> check it and also:
# - how much sets does lego dedicate to each ~~license~~ ("license" may be a german term, the english one would be franchise)
# - how do licenses differ in size / price / etc.?
#
# - source for franchises: https://en.wikipedia.org/wiki/List_of_highest-grossing_media_franchises
